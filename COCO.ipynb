# %%
import matplotlib.pyplot as plt
import torch
import torchvision
import torchvision.transforms as T
import torchvision.datasets as datasets
from torchvision.transforms import functional as F
import cv2
import random
from PIL import Image

# %%
img_folder = r"datasets/path/to/coco/train2017"
ann_file= r"datasets/path/to/coco/annotations/instances_train2017.json"

# %%
coco_det = datasets.CocoDetection(img_folder,ann_file,transform=T.ToTensor())
# Out:
# loading annotations into memory...
# Done (t=14.69s)
# creating index...
# index created!

# %%
# %matplotlib inline
print(len(coco_det)) # coco 训练集的大小，一共多少图片
print(coco_det[0][0].shape) # 第一张图的大小
print(coco_det[0][1]) # 
print(coco_det[0][1].__len__())
plt.imshow(coco_det[0][0].transpose(0,2))
print(coco_det[0][1][0].keys())
print(coco_det[0][1][0])
# Out:
# 118287
# torch.Size([3, 480, 640])
# ...
